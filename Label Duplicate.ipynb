# %%
import pandas as pd

# %%
final = pd.read_csv("C:/Users/13903/Desktop/final_table.csv")
duplicate = pd.read_excel("C:/Users/13903/Desktop/Duplicates.xlsx")
main = pd.read_excel("C:/Users/13903/Desktop/Main Records.xlsx")

# %%
duplicate_final_ID = pd.DataFrame(final['Matched ID'])
duplicate_final_ID['cluster id'] = final['cluster id']
duplicate_final_ID
# Out:
#      Matched ID  cluster id
# 0      db41c6a1         0.0
# 1      dde408f0         1.0
# 2      4e82ee4a         2.0
# 3      3eef0d37         3.0
# 4      b2bd862f         4.0
# ...         ...         ...
# 9256   c76ffc85      9256.0
# 9257   8e1e86e4      9257.0
# 9258   d22930bf      9258.0
# 9259   462f4f66      9259.0
# 9260   972ee771      9260.0
#
# [9261 rows x 2 columns]

# %%
temp = []
for i in range(len(duplicate)):
  temp.append(-1)
duplicate["cluster_id"] = temp

# %%
for j in range(len(duplicate_final_ID['Matched ID'])): 
  for i in range(len(duplicate['ID'])):
    if str(duplicate['ID'][i]) == str(duplicate_final_ID['Matched ID'][j]):
      duplicate['cluster_id'][i] = duplicate_final_ID['cluster id'][j]
      pass
# Out:
# C:\Users\13903\AppData\Local\Temp\ipykernel_16172\1673945682.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicate['cluster_id'][i] = duplicate_final_ID['cluster id'][j]

# %%
duplicate.sort_values('cluster_id')
# Out:
#             ID  Last Name First Name Date of Birth Mother's Birth Last Name  \
# 5069  fd28a28a     Zunich    Thyssen    08/25/2016                      NaN
# 5856  bda308e5     Marcom      Edgar    01/15/2019                      NaN
# 5863  88c2bc57        Mae     Ronald    01/29/2007                      NaN
# 5914  d24be1d0     Murphy       Geri    09/26/2022                      NaN
# 5928  250dea1d       Cook      Geoff    07/16/2013                      NaN
# ...        ...        ...        ...           ...                      ...
# 2274  c76ffc85     Ripley    Diahann    07/19/2020                      NaN
# 2195  8e1e86e4  Olaughlin      Rueth    06/27/2016                      NaN
# 2138  d22930bf     Briggs      Cheri    09/29/2007                      NaN
# 1923  462f4f66     Dillon      Rueth    03/23/2018                      NaN
# 1751  972ee771   Gonzalez      Knick    10/07/2013                      NaN
#
# ...

# %%
duplicates = duplicate[duplicate['cluster_id'] > -1]
duplicates
# Out:
#              ID  Last Name First Name Date of Birth Mother's Birth Last Name  \
# 0      73c2ab6a        NaN     Steven    01/13/2008                      NaN
# 1      488f1063        NaN    Dorothy    05/02/2012                      NaN
# 2      331bea71     Yerian    Ellwood    08/18/2019                      NaN
# 3      ac3aaf9c        NaN      Robin    08/25/2013                      NaN
# 4      ae9c2ae4        NaN    Raymond    05/25/2017                      NaN
# ...         ...        ...        ...           ...                      ...
# 10135  08606dd8      Avila        NaN    06/24/2014                      NaN
# 10136  8507e3f4  Fernandez        NaN    08/07/2015                      NaN
# 10137  d5285223    Mathews        NaN    02/28/2015                      NaN
# 10138  7157d300      Konty        NaN    12/15/2022                      NaN
# 10139  8f88ce49   Knowlton        NaN    10/24/2018                      NaN
#
# ...

# %%
#duplicate.to_csv("C:/Users/ZZH/Desktop/error_duplicate.csv", index=False, encoding='utf-8')
duplicates.to_csv("C:/Users/13903/Desktop/duplicate.csv", index=False, encoding='utf-8')
#duplicate_ = pd.read_csv("C:/Users/ZZH/Desktop/duplicate.csv")

# %%
#duplicate_.sort_values(['cluster_id'], inplace = True)
#duplicate.to_csv('C:/Users/ZZH/Desktop/duplicate.csv')
duplicate_ = pd.read_csv("C:/Users/13903/Desktop/duplicate.csv")
duplicate_
# Out:
#             ID  Last Name First Name Date of Birth Mother's Birth Last Name  \
# 0     73c2ab6a        NaN     Steven    01/13/2008                      NaN
# 1     488f1063        NaN    Dorothy    05/02/2012                      NaN
# 2     331bea71     Yerian    Ellwood    08/18/2019                      NaN
# 3     ac3aaf9c        NaN      Robin    08/25/2013                      NaN
# 4     ae9c2ae4        NaN    Raymond    05/25/2017                      NaN
# ...        ...        ...        ...           ...                      ...
# 9256  08606dd8      Avila        NaN    06/24/2014                      NaN
# 9257  8507e3f4  Fernandez        NaN    08/07/2015                      NaN
# 9258  d5285223    Mathews        NaN    02/28/2015                      NaN
# 9259  7157d300      Konty        NaN    12/15/2022                      NaN
# 9260  8f88ce49   Knowlton        NaN    10/24/2018                      NaN
#
# ...

# %%
duplicate_.sort_values(['cluster_id'])
# Out:
#             ID  Last Name First Name Date of Birth Mother's Birth Last Name  \
# 1551  db41c6a1        NaN    Camilla    04/29/2022                      NaN
# 1550  dde408f0        NaN    Yolanda    05/15/2018                      NaN
# 1549  4e82ee4a        NaN     Marion    08/28/2022                      NaN
# 1547  3eef0d37        NaN      Jesse    06/13/2016                      NaN
# 1546  b2bd862f        NaN       Jean    07/09/2012                      NaN
# ...        ...        ...        ...           ...                      ...
# 2204  c76ffc85     Ripley    Diahann    07/19/2020                      NaN
# 2132  8e1e86e4  Olaughlin      Rueth    06/27/2016                      NaN
# 2079  d22930bf     Briggs      Cheri    09/29/2007                      NaN
# 1868  462f4f66     Dillon      Rueth    03/23/2018                      NaN
# 1704  972ee771   Gonzalez      Knick    10/07/2013                      NaN
#
# ...

# %%
'''duplicate_labeled = duplicate_[duplicate_['cluster_id'] > -1]
duplicate_labeled.reset_index(drop =True, inplace=True)
duplicate_labeled.drop(duplicate_labeled.columns[0], axis = 1, inplace = True)
duplicate_labeled.to_csv("C:/Users/ZZH/Desktop/duplicate.csv", index=False, encoding='utf-8')'''
# Out:
# 'duplicate_labeled = duplicate_[duplicate_[\'cluster_id\'] > -1]\nduplicate_labeled.reset_index(drop =True, inplace=True)\nduplicate_labeled.drop(duplicate_labeled.columns[0], axis = 1, inplace = True)\nduplicate_labeled.to_csv("C:/Users/ZZH/Desktop/duplicate.csv", index=False, encoding=\'utf-8\')'
