# %%
import pandas as pd

# %%
final = pd.read_csv("C:/Users/13903/Desktop/final table.csv")
final
# Out:
#        Unnamed: 0 Citizenship Date of Birth         Ethnicity First Name  \
# 0               0      canada    04/29/2022   native hawaiian    camilla
# 1               1      canada    05/15/2018               NaN    yolanda
# 2               2      canada    08/28/2022               NaN     marion
# 3               3      canada    06/13/2016  middle easterner      jesse
# 4               4         NaN    07/09/2012               NaN       jean
# ...           ...         ...           ...               ...        ...
# 10135       10135      canada    08/15/2015               NaN        guy
# 10136       10136         NaN    08/07/2017          hispanic   michelle
# 10137       10137      canada    06/08/2022               NaN        bob
# 10138       10138      canada    04/24/2020   native hawaiian     jarred
# 10139       10139      canada    11/29/2011        east asian        jim
#
#              ID Indigenous Identity Language (Mother Tongue)  Last Name  \
# ...

# %%
new_final = final[final['confidence'] > 0.6]
new_final
# Out:
#       Unnamed: 0 Citizenship Date of Birth         Ethnicity First Name  \
# 0              0      canada    04/29/2022   native hawaiian    camilla
# 1              1      canada    05/15/2018               NaN    yolanda
# 2              2      canada    08/28/2022               NaN     marion
# 3              3      canada    06/13/2016  middle easterner      jesse
# 4              4         NaN    07/09/2012               NaN       jean
# ...          ...         ...           ...               ...        ...
# 9256        9256      canada    07/19/2020   native hawaiian      diane
# 9257        9257      canada    06/27/2016   american indian       ruth
# 9258        9258      canada    09/29/2007     alaska native    sherrie
# 9259        9259      canada    03/23/2018     alaska native       ruth
# 9260        9260      canada    10/07/2013               NaN       nick
#
#             ID Indigenous Identity Language (Mother Tongue)  Last Name  \
# ...

# %%
new_final.to_csv("C:/Users/13903/Desktop/final_table.csv", index=False, encoding='utf-8')
